# %%
from functions.base_market import get_public_recent_trading_history
get_public_recent_trading_history(category='inverse', symbol="BTCUSD")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'inverse',
#   'list': [{'execId': '8dd2c598-7ee4-5044-97ef-e00db6699242',
#     'symbol': 'BTCUSD',
#     'price': '95915.50',
#     'size': '35',
#     'side': 'Buy',
#     'time': '1739130378619',
#     'isBlockTrade': False},
#    {'execId': 'bb1da314-f6a6-5251-819d-9157a33af426',
#     'symbol': 'BTCUSD',
#     'price': '95925.50',
#     'size': '25',
#     'side': 'Sell',
#     'time': '1739130375225',
#     'isBlockTrade': False},
#    {'execId': 'c5e5c2b9-52ac-5aca-887b-307d01d9bc7c',
#     'symbol': 'BTCUSD',
#     'price': '95907.50',
#     'size': '1',
#     'side': 'Buy',
#     'time': '1739130372686',
#     'isBlockTrade': False},
#    {'execId': '30bc6a2b-6b36-5fe7-a19e-9c77f4230c5a',
#     'symbol': 'BTCUSD',
#     'price': '95901.00',
#     'size': '5',
#     'side': 'Buy',
#     'time': '1739130368200',
#     'isBlockTrade': False},
#    {'execId': '1885adad-bd5d-5e63-9010-e8dafd960619',
# ...

# %%
from functions.base_trade import place_order

place_order(category="linear",
    symbol="BTCUSDT",
    side="Buy",
    order_type="Limit",
    qty="0.001",
    price="15600",
    time_in_force="GTC",
    is_leverage=0,
    order_filter="Order")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'orderId': '8c8f0973-c60c-4837-94d2-4fc4cf1cfb6a',
#   'orderLinkId': 'e43842f374614cd2af6bf5daa3e76bf9'},
#  'retExtInfo': {},
#  'time': 1739184659833}

# %%
from functions.base_trade import get_open_and_closed_orders

get_open_and_closed_orders(category="linear",

                           open_only=0,)
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': '', 'category': 'linear', 'list': []},
#  'retExtInfo': {},
#  'time': 1739185010643}
